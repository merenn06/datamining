# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Sample dataset
np.random.seed(42)
data = pd.DataFrame({
    "Exam 1": np.random.normal(60, 10, 100),
    "Exam 2": np.random.normal(70, 15, 100),
    "Exam 3": np.random.normal(50, 20, 100)
})

# Boxplot visualization
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title("Boxplot Analysis - Score Distribution of 3 Exams")
plt.ylabel("Score")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Topic 2 – Boxplot Analysis
#
# In this notebook, we visualize the distribution of scores from three different exams using a boxplot.
#
# - A boxplot is a standardized way of displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
# - It also helps to identify outliers in the dataset.
# - We used `seaborn.boxplot()` to create a boxplot for the three exams.
#
# The plot provides insight into:
# - Central tendency (median),
# - Spread (interquartile range),
# - Symmetry/skewness of the data,
# - Presence of outliers.
