# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes model
nb = GaussianNB()
nb.fit(X_train, y_train)

# Predict
y_pred = nb.predict(X_test)

# Print results
print(classification_report(y_test, y_pred, target_names=iris.target_names))

# Confusion matrix
ConfusionMatrixDisplay.from_estimator(nb, X_test, y_test, display_labels=iris.target_names, cmap='Greens')
plt.title("Naive Bayes – Confusion Matrix")
plt.grid(False)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### Topic 18 – Naive Bayes Classification
#
# In this notebook, we use **Naive Bayes** to classify the Iris dataset.
#
# Steps:
# 1. Loaded the Iris dataset.
# 2. Split into training and test sets.
# 3. Trained a Gaussian Naive Bayes classifier.
# 4. Evaluated predictions using a classification report and confusion matrix.
#
# Naive Bayes is based on:
# - Bayes’ Theorem,
# - The assumption that features are conditionally independent (naive assumption).
#
# Advantages:
# - Very fast and simple,
# - Works well with high-dimensional data,
# - Commonly used for text classification (e.g., spam filtering).
